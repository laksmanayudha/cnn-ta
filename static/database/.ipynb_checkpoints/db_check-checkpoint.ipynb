# %%
import pandas as pd

pd.read_csv("database.csv")
# Out:
#    Unnamed: 0        filename  \
# 0           0  lifestyle0.txt
# 1           1       news0.txt
# 2           2   otomotif0.txt
# 3           3  teknologi0.txt
#
#                                                 text  \
# 0  Speedmaster Moonswatch, Kolaborasi Nyeleneh Om...
# 1  Keluarga Surati Kapolri soal Kasus Kematian Ak...
# 2  Yamaha XSR 155 Custom, Big Wheels Bike\nYOGYAK...
# 3  Cara Transfer GoPay ke ShopeePay dengan Mudah ...
#
#                                                 prob   category      bola  \
# 0  [1.6985006e-06 6.4834021e-06 9.9993324e-01 1.8...  lifestyle  0.000002
# 1  [1.0801266e-05 1.2002160e-06 3.1746382e-05 9.9...       news  0.000011
# 2  [1.3465828e-05 1.2193529e-05 3.9700029e-05 2.7...   otomotif  0.000013
# 3  [2.2514751e-03 1.3502655e-04 9.3695091e-04 5.6...  teknologi  0.002251
#
#      health  lifestyle          news  otomotif  teknologi
# 0  0.000006   0.999933  1.888433e-07  0.000013   0.000046
# ...
